# %%
import pandas as pd

# %%
data = {
    'Empleado': ['Juan', 'Ana', 'Pedro', 'Luis', 'Maria', 'Ana', 'Pedro', 'Luis', 'Maria'],
    'Departamento': ['Ventas', 'Marketing', 'Ventas', 'IT', 'Marketing', 'IT', 'Ventas', 'Marketing', 'Ventas'],
    'Salario': [50000, 60000, 55000, 58000, 62000, 60000, 55000, 58000, 62000],
    'Años_Experiencia': [5, 7, 6, 8, 9, 7, 6, 8, 9]
}
df = pd.DataFrame(data)
display(df)
# Out:
#   Empleado Departamento  Salario  Años_Experiencia
# 0     Juan       Ventas    50000                 5
# 1      Ana    Marketing    60000                 7
# 2    Pedro       Ventas    55000                 6
# 3     Luis           IT    58000                 8
# 4    Maria    Marketing    62000                 9
# 5      Ana           IT    60000                 7
# 6    Pedro       Ventas    55000                 6
# 7     Luis    Marketing    58000                 8
# 8    Maria       Ventas    62000                 9

# %%
df['Salario_Normalizado'] = df.groupby('Departamento')['Salario'].transform(lambda x: (x - x.mean()) / x.std())
display(df)
# Out:
#   Empleado Departamento  Salario  Años_Experiencia  Salario_Normalizado
# 0     Juan       Ventas    50000                 5            -1.114967
# 1      Ana    Marketing    60000                 7             0.000000
# 2    Pedro       Ventas    55000                 6            -0.101361
# 3     Luis           IT    58000                 8            -0.707107
# 4    Maria    Marketing    62000                 9             1.000000
# 5      Ana           IT    60000                 7             0.707107
# 6    Pedro       Ventas    55000                 6            -0.101361
# 7     Luis    Marketing    58000                 8            -1.000000
# 8    Maria       Ventas    62000                 9             1.317688

# %%
df_filtrado = df.groupby('Departamento').filter(lambda x: len(x) > 2)
display(df_filtrado)
# Out:
#   Empleado Departamento  Salario  Años_Experiencia  Salario_Normalizado
# 0     Juan       Ventas    50000                 5            -1.114967
# 1      Ana    Marketing    60000                 7             0.000000
# 2    Pedro       Ventas    55000                 6            -0.101361
# 4    Maria    Marketing    62000                 9             1.000000
# 6    Pedro       Ventas    55000                 6            -0.101361
# 7     Luis    Marketing    58000                 8            -1.000000
# 8    Maria       Ventas    62000                 9             1.317688

# %%
agregaciones_diferentes = df.groupby('Departamento').agg({
    'Salario': 'sum',
    'Años_Experiencia': 'mean'
})
display(agregaciones_diferentes)
# Out:
#               Salario  Años_Experiencia
# Departamento
# IT             118000               7.5
# Marketing      180000               8.0
# Ventas         222000               6.5

# %%
data = {
    'Fecha': pd.date_range(start='2023-01-01', periods=90, freq='D'),
    'Ventas': [i * 100 for i in range(90)]
}
df_ventas = pd.DataFrame(data)
display(df_ventas)
# Out:
#         Fecha  Ventas
# 0  2023-01-01       0
# 1  2023-01-02     100
# 2  2023-01-03     200
# 3  2023-01-04     300
# 4  2023-01-05     400
# ..        ...     ...
# 85 2023-03-27    8500
# 86 2023-03-28    8600
# 87 2023-03-29    8700
# 88 2023-03-30    8800
# 89 2023-03-31    8900
#
# [90 rows x 2 columns]

# %%
df_ventas.set_index('Fecha', inplace=True)
display(df_ventas)
# Out:
#             Ventas
# Fecha
# 2023-01-01       0
# 2023-01-02     100
# 2023-01-03     200
# 2023-01-04     300
# 2023-01-05     400
# ...            ...
# 2023-03-27    8500
# 2023-03-28    8600
# 2023-03-29    8700
# 2023-03-30    8800
# 2023-03-31    8900
#
# [90 rows x 1 columns]

# %%
ventas_mensuales = df_ventas.groupby(pd.Grouper(freq='M')).mean()
display(ventas_mensuales)
# Out:
#             Ventas
# Fecha
# 2023-01-31  1500.0
# 2023-02-28  4450.0
# 2023-03-31  7400.0

# %%
def rango_salarios(grupo):
    return grupo['Salario'].max() - grupo['Salario'].min()

# %%
rango_salarios_por_departamento = df.groupby('Departamento').apply(rango_salarios)
display(rango_salarios_por_departamento)
# Out:
# Departamento
# IT            2000
# Marketing     4000
# Ventas       12000
# dtype: int64
